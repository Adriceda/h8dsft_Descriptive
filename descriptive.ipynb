# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sympy as sy
from sympy.tensor.array import derive_by_array
import random

# %% [markdown]
# # FILE LOAD

# %%
# Load Dataset
data = pd.read_csv('covid_19_indonesia_time_series_all.csv')

# %%
data.head()
# Out:
#        Date Location ISO Code     Location  New Cases  New Deaths  \
# 0  3/1/2020             ID-JK  DKI Jakarta          2           0
# 1  3/2/2020             ID-JK  DKI Jakarta          2           0
# 2  3/2/2020               IDN    Indonesia          2           0
# 3  3/2/2020             ID-RI         Riau          1           0
# 4  3/3/2020             ID-JK  DKI Jakarta          2           0
#
#    New Recovered  New Active Cases  Total Cases  Total Deaths  \
# 0              0                 2           39            20
# 1              0                 2           41            20
# 2              0                 2            2             0
# 3              0                 1            1             0
# 4              0                 2           43            20
#
#    Total Recovered  ...  Latitude New Cases per Million  \
# 0               75  ... -6.204699                  0.18
# 1               75  ... -6.204699                  0.18
# 2                0  ... -0.789275                  0.01
# 3                1  ...  0.511648                  0.16
# 4               75  ... -6.204699                  0.18
#
#    Total Cases per Million New Deaths per Million Total Deaths per Million  \
# 0                     3.60                    0.0                     1.84
# 1                     3.78                    0.0                     1.84
# 2                     0.01                    0.0                     0.00
# 3                     0.16                    0.0                     0.00
# 4                     3.96                    0.0                     1.84
#
#   Total Deaths per 100rb Case Fatality Rate Case Recovered Rate  \
# 0                   0.18             51.28%             192.31%
# 1                   0.18             48.78%             182.93%
# 2                   0.00              0.00%               0.00%
# 3                   0.00              0.00%             100.00%
# 4                   0.18             46.51%             174.42%
#
#   Growth Factor of New Cases  Growth Factor of New Deaths
# 0                        NaN                          NaN
# 1                        1.0                          1.0
# 2                        NaN                          NaN
# 3                        NaN                          NaN
# 4                        1.0                          1.0
#
# [5 rows x 38 columns]

# %%
# Get All Columns
data.columns
# Out:
# Index(['Date', 'Location ISO Code', 'Location', 'New Cases', 'New Deaths',
#        'New Recovered', 'New Active Cases', 'Total Cases', 'Total Deaths',
#        'Total Recovered', 'Total Active Cases', 'Location Level',
#        'City or Regency', 'Province', 'Country', 'Continent', 'Island',
#        'Time Zone', 'Special Status', 'Total Regencies', 'Total Cities',
#        'Total Districts', 'Total Urban Villages', 'Total Rural Villages',
#        'Area (km2)', 'Population', 'Population Density', 'Longitude',
#        'Latitude', 'New Cases per Million', 'Total Cases per Million',
#        'New Deaths per Million', 'Total Deaths per Million',
#        'Total Deaths per 100rb', 'Case Fatality Rate', 'Case Recovered Rate',
#        'Growth Factor of New Cases', 'Growth Factor of New Deaths'],
#       dtype='object')

# %%
# Get Type of All Columns
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31822 entries, 0 to 31821
# Data columns (total 38 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Date                         31822 non-null  object
#  1   Location ISO Code            31822 non-null  object
#  2   Location                     31822 non-null  object
#  3   New Cases                    31822 non-null  int64
#  4   New Deaths                   31822 non-null  int64
#  5   New Recovered                31822 non-null  int64
#  6   New Active Cases             31822 non-null  int64
#  7   Total Cases                  31822 non-null  int64
#  8   Total Deaths                 31822 non-null  int64
#  9   Total Recovered              31822 non-null  int64
#  10  Total Active Cases           31822 non-null  int64
#  11  Location Level               31822 non-null  object
#  12  City or Regency              0 non-null      float64
#  13  Province                     30893 non-null  object
#  14  Country                      31822 non-null  object
#  15  Continent                    31822 non-null  object
#  16  Island                       30893 non-null  object
#  17  Time Zone                    30893 non-null  object
#  18  Special Status               4558 non-null   object
#  19  Total Regencies              31822 non-null  int64
#  20  Total Cities                 30921 non-null  float64
#  21  Total Districts              31822 non-null  int64
#  22  Total Urban Villages         30918 non-null  float64
#  23  Total Rural Villages         30893 non-null  float64
#  24  Area (km2)                   31822 non-null  int64
#  25  Population                   31822 non-null  int64
#  26  Population Density           31822 non-null  float64
#  27  Longitude                    31822 non-null  float64
#  28  Latitude                     31822 non-null  float64
#  29  New Cases per Million        31822 non-null  float64
#  30  Total Cases per Million      31822 non-null  float64
#  31  New Deaths per Million       31822 non-null  float64
#  32  Total Deaths per Million     31822 non-null  float64
#  33  Total Deaths per 100rb       31822 non-null  float64
#  34  Case Fatality Rate           31822 non-null  object
#  35  Case Recovered Rate          31822 non-null  object
#  36  Growth Factor of New Cases   29883 non-null  float64
#  37  Growth Factor of New Deaths  28375 non-null  float64
# dtypes: float64(14), int64(12), object(12)
# memory usage: 9.2+ MB

# %% [markdown]
# # DATA CLEANING

# %%
## Select only numeric features
data_num = data.select_dtypes(include= np.number)

## Save the name of numeric features into a list
columns_num = data_num.columns.to_list()

data_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31822 entries, 0 to 31821
# Data columns (total 26 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   New Cases                    31822 non-null  int64
#  1   New Deaths                   31822 non-null  int64
#  2   New Recovered                31822 non-null  int64
#  3   New Active Cases             31822 non-null  int64
#  4   Total Cases                  31822 non-null  int64
#  5   Total Deaths                 31822 non-null  int64
#  6   Total Recovered              31822 non-null  int64
#  7   Total Active Cases           31822 non-null  int64
#  8   City or Regency              0 non-null      float64
#  9   Total Regencies              31822 non-null  int64
#  10  Total Cities                 30921 non-null  float64
#  11  Total Districts              31822 non-null  int64
#  12  Total Urban Villages         30918 non-null  float64
#  13  Total Rural Villages         30893 non-null  float64
#  14  Area (km2)                   31822 non-null  int64
#  15  Population                   31822 non-null  int64
#  16  Population Density           31822 non-null  float64
#  17  Longitude                    31822 non-null  float64
#  18  Latitude                     31822 non-null  float64
#  19  New Cases per Million        31822 non-null  float64
#  20  Total Cases per Million      31822 non-null  float64
#  21  New Deaths per Million       31822 non-null  float64
#  22  Total Deaths per Million     31822 non-null  float64
#  23  Total Deaths per 100rb       31822 non-null  float64
#  24  Growth Factor of New Cases   29883 non-null  float64
#  25  Growth Factor of New Deaths  28375 non-null  float64
# dtypes: float64(14), int64(12)
# memory usage: 6.3 MB

# %%
# Check If Dataset Contains Missing Values

for col in columns_num:
  total_missing = data[col].isnull().sum()
  if total_missing > 0:
    print(col, ' : ', total_missing)
# Out:
# City or Regency  :  31822
# Total Cities  :  901
# Total Urban Villages  :  904
# Total Rural Villages  :  929
# Growth Factor of New Cases  :  1939
# Growth Factor of New Deaths  :  3447

# %% [markdown]
# - Column to be removed
#
# City or Regency
#
# - Column to fix
#
# Total Cities, Total Urban Villages, Total Rural Villages, Growth Factor of New Cases, Growth Factor of New Deaths

# %%
#Feature: Total Cities
print('Skewness value : ', data['Total Cities'].skew())
data['Total Cities'].hist(bins=50, figsize=(10,5), color='maroon')
plt.show()
# Out:
# Skewness value :  5.330543047780366

# %%
#Feature: Total Urban Villages
print('Skewness value : ', data['Total Urban Villages'].skew())
data['Total Urban Villages'].hist(bins=50, figsize=(10,5), color='maroon')
plt.show()
# Out:
# Skewness value :  5.3023044702948585

# %%
#Feature: Total Rural Villages
print('Skewness value : ', data['Total Rural Villages'].skew())
data['Total Rural Villages'].hist(bins=50, figsize=(10,5), color='maroon')
plt.show()
# Out:
# Skewness value :  5.275090820471407

# %%
#Feature: Growth Factor of New Cases

print('Skewness value : ', data['Growth Factor of New Cases'].skew())
data['Growth Factor of New Cases'].hist(bins=100, figsize=(10,5), color='maroon')
plt.show()
# Out:
# Skewness value :  23.392045876971395

# %%
#Feature: Growth Factor of New Deaths

print('Skewness value : ', data['Growth Factor of New Deaths'].skew())
data['Growth Factor of New Deaths'].hist(bins=100, figsize=(10,5), color='maroon')
plt.show()
# Out:
# Skewness value :  39.289569553723936

# %%
data.describe().T
# Out:
#                                count          mean           std  \
# New Cases                    31822.0  4.023114e+02  2.320630e+03
# New Deaths                   31822.0  9.920652e+00  6.413908e+01
# New Recovered                31822.0  3.903985e+02  2.199879e+03
# New Active Cases             31822.0  1.992238e+00  1.219513e+03
# Total Cases                  31822.0  1.594500e+05  6.264435e+05
# Total Deaths                 31822.0  4.564753e+03  1.769373e+04
# Total Recovered              31822.0  1.492615e+05  5.958536e+05
# Total Active Cases           31822.0  5.623782e+03  2.853741e+04
# City or Regency                  0.0           NaN           NaN
# Total Regencies              31822.0  2.402728e+01  6.835973e+01
# Total Cities                 30921.0  5.835840e+00  1.639012e+01
# Total Districts              31822.0  4.179523e+02  1.192995e+03
# Total Urban Villages         30918.0  5.055139e+02  1.422071e+03
# Total Rural Villages         30893.0  4.462493e+03  1.258274e+04
# Area (km2)                   31822.0  1.106532e+05  3.187865e+05
# Population                   31822.0  1.536766e+07  4.461714e+07
# Population Density           31822.0  7.388949e+02  2.729432e+03
# Longitude                    31822.0  1.137005e+02  9.862068e+00
# Latitude                     31822.0 -2.725681e+00  3.608065e+00
# New Cases per Million        31822.0  2.813329e+01  7.430971e+01
# Total Cases per Million      31822.0  1.148504e+04  1.647739e+04
# New Deaths per Million       31822.0  6.403083e-01  1.933016e+00
# Total Deaths per Million     31822.0  2.896336e+02  3.634287e+02
# Total Deaths per 100rb       31822.0  2.896333e+01  3.634288e+01
# Growth Factor of New Cases   29883.0  1.326795e+00  2.679379e+00
# Growth Factor of New Deaths  28375.0  1.033834e+00  1.351755e+00
#
#                                        min           25%           50%  \
# New Cases                         0.000000  3.000000e+00  2.700000e+01
# New Deaths                        0.000000  0.000000e+00  0.000000e+00
# New Recovered                     0.000000  2.000000e+00  2.000000e+01
# New Active Cases             -29938.000000 -1.200000e+01  0.000000e+00
# Total Cases                       1.000000  5.223250e+03  2.359650e+04
# Total Deaths                      0.000000  1.280000e+02  5.655000e+02
# Total Recovered                   0.000000  3.913500e+03  2.102750e+04
# Total Active Cases            -2343.000000  8.000000e+01  5.570000e+02
# City or Regency                        NaN           NaN           NaN
# Total Regencies                   1.000000  7.000000e+00  1.100000e+01
# Total Cities                      1.000000  1.000000e+00  2.000000e+00
# Total Districts                  44.000000  1.030000e+02  1.690000e+02
# Total Urban Villages             35.000000  9.900000e+01  1.750000e+02
# Total Rural Villages            275.000000  9.280000e+02  1.591000e+03
# Area (km2)                      664.000000  1.678700e+04  4.201300e+04
# Population                   648407.000000  1.999539e+06  4.216171e+06
# Population Density                8.590000  4.779000e+01  1.038400e+02
# Longitude                        96.910522  1.061090e+02  1.134177e+02
# Latitude                         -8.682205 -6.204699e+00 -2.461746e+00
# New Cases per Million             0.000000  8.300000e-01  5.710000e+00
# Total Cases per Million           0.010000  1.291367e+03  6.804285e+03
# New Deaths per Million            0.000000  0.000000e+00  0.000000e+00
# Total Deaths per Million          0.000000  3.886250e+01  1.584150e+02
# Total Deaths per 100rb            0.000000  3.890000e+00  1.584000e+01
# Growth Factor of New Cases        0.000000  6.500000e-01  1.000000e+00
# Growth Factor of New Deaths       0.000000  7.500000e-01  1.000000e+00
#
#                                       75%           max
# New Cases                    1.300000e+02  6.471800e+04
# New Deaths                   3.000000e+00  2.069000e+03
# New Recovered                1.230000e+02  6.136100e+04
# New Active Cases             1.900000e+01  3.916500e+04
# Total Cases                  6.992775e+04  6.405044e+06
# Total Deaths                 2.189000e+03  1.578760e+05
# Total Recovered              6.414200e+04  6.218708e+06
# Total Active Cases           2.279000e+03  5.861130e+05
# City or Regency                       NaN           NaN
# Total Regencies              1.800000e+01  4.160000e+02
# Total Cities                 4.000000e+00  9.800000e+01
# Total Districts              2.890000e+02  7.230000e+03
# Total Urban Villages         3.320000e+02  8.488000e+03
# Total Rural Villages         2.853000e+03  7.495300e+04
# Area (km2)                   7.546800e+04  1.916907e+06
# Population                   9.095591e+06  2.651855e+08
# Population Density           2.627000e+02  1.633431e+04
# Longitude                    1.212011e+02  1.386960e+02
# Latitude                     2.120369e-01  4.225615e+00
# New Cases per Million        2.229000e+01  1.459040e+03
# Total Cases per Million      1.455736e+04  1.302316e+05
# New Deaths per Million       5.400000e-01  6.380000e+01
# Total Deaths per Million     3.899100e+02  1.632600e+03
# Total Deaths per 100rb       3.899000e+01  1.632600e+02
# Growth Factor of New Cases   1.310000e+00  1.750000e+02
# Growth Factor of New Deaths  1.000000e+00  1.345000e+02

# %%
# Handling Missing Values using Median
#Total Cities, Total Urban Villages, Total Rural Villages, Growth Factor of New Cases, Growth Factor of New Deaths
data['Total Cities'] = data['Total Cities'].fillna(data['Total Cities'].median())
data['Total Urban Villages'] = data['Total Urban Villages'].fillna(data['Total Urban Villages'].median())
data['Total Rural Villages'] = data['Total Rural Villages'].fillna(data['Total Rural Villages'].median())
data['Growth Factor of New Cases'] = data['Growth Factor of New Cases'].fillna(data['Growth Factor of New Cases'].median())
data['Growth Factor of New Deaths'] = data['Growth Factor of New Deaths'].fillna(data['Growth Factor of New Deaths'].median())
data.describe().T
# Out:
#                                count          mean           std  \
# New Cases                    31822.0  4.023114e+02  2.320630e+03
# New Deaths                   31822.0  9.920652e+00  6.413908e+01
# New Recovered                31822.0  3.903985e+02  2.199879e+03
# New Active Cases             31822.0  1.992238e+00  1.219513e+03
# Total Cases                  31822.0  1.594500e+05  6.264435e+05
# Total Deaths                 31822.0  4.564753e+03  1.769373e+04
# Total Recovered              31822.0  1.492615e+05  5.958536e+05
# Total Active Cases           31822.0  5.623782e+03  2.853741e+04
# City or Regency                  0.0           NaN           NaN
# Total Regencies              31822.0  2.402728e+01  6.835973e+01
# Total Cities                 31822.0  5.727233e+00  1.616894e+01
# Total Districts              31822.0  4.179523e+02  1.192995e+03
# Total Urban Villages         31822.0  4.961247e+02  1.402801e+03
# Total Rural Villages         31822.0  4.378663e+03  1.240712e+04
# Area (km2)                   31822.0  1.106532e+05  3.187865e+05
# Population                   31822.0  1.536766e+07  4.461714e+07
# Population Density           31822.0  7.388949e+02  2.729432e+03
# Longitude                    31822.0  1.137005e+02  9.862068e+00
# Latitude                     31822.0 -2.725681e+00  3.608065e+00
# New Cases per Million        31822.0  2.813329e+01  7.430971e+01
# Total Cases per Million      31822.0  1.148504e+04  1.647739e+04
# New Deaths per Million       31822.0  6.403083e-01  1.933016e+00
# Total Deaths per Million     31822.0  2.896336e+02  3.634287e+02
# Total Deaths per 100rb       31822.0  2.896333e+01  3.634288e+01
# Growth Factor of New Cases   31822.0  1.306883e+00  2.597639e+00
# Growth Factor of New Deaths  31822.0  1.030169e+00  1.276486e+00
#
#                                        min           25%           50%  \
# New Cases                         0.000000  3.000000e+00  2.700000e+01
# New Deaths                        0.000000  0.000000e+00  0.000000e+00
# New Recovered                     0.000000  2.000000e+00  2.000000e+01
# New Active Cases             -29938.000000 -1.200000e+01  0.000000e+00
# Total Cases                       1.000000  5.223250e+03  2.359650e+04
# Total Deaths                      0.000000  1.280000e+02  5.655000e+02
# Total Recovered                   0.000000  3.913500e+03  2.102750e+04
# Total Active Cases            -2343.000000  8.000000e+01  5.570000e+02
# City or Regency                        NaN           NaN           NaN
# Total Regencies                   1.000000  7.000000e+00  1.100000e+01
# Total Cities                      1.000000  1.000000e+00  2.000000e+00
# Total Districts                  44.000000  1.030000e+02  1.690000e+02
# Total Urban Villages             35.000000  9.900000e+01  1.750000e+02
# Total Rural Villages            275.000000  9.280000e+02  1.591000e+03
# Area (km2)                      664.000000  1.678700e+04  4.201300e+04
# Population                   648407.000000  1.999539e+06  4.216171e+06
# Population Density                8.590000  4.779000e+01  1.038400e+02
# Longitude                        96.910522  1.061090e+02  1.134177e+02
# Latitude                         -8.682205 -6.204699e+00 -2.461746e+00
# New Cases per Million             0.000000  8.300000e-01  5.710000e+00
# Total Cases per Million           0.010000  1.291367e+03  6.804285e+03
# New Deaths per Million            0.000000  0.000000e+00  0.000000e+00
# Total Deaths per Million          0.000000  3.886250e+01  1.584150e+02
# Total Deaths per 100rb            0.000000  3.890000e+00  1.584000e+01
# Growth Factor of New Cases        0.000000  6.700000e-01  1.000000e+00
# Growth Factor of New Deaths       0.000000  8.800000e-01  1.000000e+00
#
#                                       75%           max
# New Cases                    1.300000e+02  6.471800e+04
# New Deaths                   3.000000e+00  2.069000e+03
# New Recovered                1.230000e+02  6.136100e+04
# New Active Cases             1.900000e+01  3.916500e+04
# Total Cases                  6.992775e+04  6.405044e+06
# Total Deaths                 2.189000e+03  1.578760e+05
# Total Recovered              6.414200e+04  6.218708e+06
# Total Active Cases           2.279000e+03  5.861130e+05
# City or Regency                       NaN           NaN
# Total Regencies              1.800000e+01  4.160000e+02
# Total Cities                 4.000000e+00  9.800000e+01
# Total Districts              2.890000e+02  7.230000e+03
# Total Urban Villages         3.320000e+02  8.488000e+03
# Total Rural Villages         2.853000e+03  7.495300e+04
# Area (km2)                   7.546800e+04  1.916907e+06
# Population                   9.095591e+06  2.651855e+08
# Population Density           2.627000e+02  1.633431e+04
# Longitude                    1.212011e+02  1.386960e+02
# Latitude                     2.120369e-01  4.225615e+00
# New Cases per Million        2.229000e+01  1.459040e+03
# Total Cases per Million      1.455736e+04  1.302316e+05
# New Deaths per Million       5.400000e-01  6.380000e+01
# Total Deaths per Million     3.899100e+02  1.632600e+03
# Total Deaths per 100rb       3.899000e+01  1.632600e+02
# Growth Factor of New Cases   1.250000e+00  1.750000e+02
# Growth Factor of New Deaths  1.000000e+00  1.345000e+02

# %%
# Check If Dataset Contains Missing Values

for col in columns_num:
  total_missing = data[col].isnull().sum()
  print(col, ' : ', total_missing)

print('Total Columns : ', len(columns_num))
# Out:
# New Cases  :  0
# New Deaths  :  0
# New Recovered  :  0
# New Active Cases  :  0
# Total Cases  :  0
# Total Deaths  :  0
# Total Recovered  :  0
# Total Active Cases  :  0
# City or Regency  :  31822
# Total Regencies  :  0
# Total Cities  :  0
# Total Districts  :  0
# Total Urban Villages  :  0
# Total Rural Villages  :  0
# Area (km2)  :  0
# Population  :  0
# Population Density  :  0
# Longitude  :  0
# Latitude  :  0
# New Cases per Million  :  0
# Total Cases per Million  :  0
# New Deaths per Million  :  0
# Total Deaths per Million  :  0
# Total Deaths per 100rb  :  0
# Growth Factor of New Cases  :  0
# Growth Factor of New Deaths  :  0
# Total Columns :  26

# %% [markdown]
# CARI MEASURE OF CENTRAL TENDENCY
# - mean
# - median
# - mode
# - midrange

# %%
print(data.mean())
# data.midrange()
# Out:
# New Cases                      4.023114e+02
# New Deaths                     9.920652e+00
# New Recovered                  3.903985e+02
# New Active Cases               1.992238e+00
# Total Cases                    1.594500e+05
# Total Deaths                   4.564753e+03
# Total Recovered                1.492615e+05
# Total Active Cases             5.623782e+03
# City or Regency                         NaN
# Total Regencies                2.402728e+01
# Total Cities                   5.727233e+00
# Total Districts                4.179523e+02
# Total Urban Villages           4.961247e+02
# Total Rural Villages           4.378663e+03
# Area (km2)                     1.106532e+05
# Population                     1.536766e+07
# Population Density             7.388949e+02
# Longitude                      1.137005e+02
# Latitude                      -2.725681e+00
# New Cases per Million          2.813329e+01
# Total Cases per Million        1.148504e+04
# New Deaths per Million         6.403083e-01
# Total Deaths per Million       2.896336e+02
# Total Deaths per 100rb         2.896333e+01
# Growth Factor of New Cases     1.306883e+00
# Growth Factor of New Deaths    1.030169e+00
# dtype: float64
# /var/folders/4s/n8nwg7s545s2kjgr2ts9qlkc0000gn/T/ipykernel_61688/2918388515.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(data.mean())

# %%
print(data.median())
# Out:
# New Cases                      2.700000e+01
# New Deaths                     0.000000e+00
# New Recovered                  2.000000e+01
# New Active Cases               0.000000e+00
# Total Cases                    2.359650e+04
# Total Deaths                   5.655000e+02
# Total Recovered                2.102750e+04
# Total Active Cases             5.570000e+02
# City or Regency                         NaN
# Total Regencies                1.100000e+01
# Total Cities                   2.000000e+00
# Total Districts                1.690000e+02
# Total Urban Villages           1.750000e+02
# Total Rural Villages           1.591000e+03
# Area (km2)                     4.201300e+04
# Population                     4.216171e+06
# Population Density             1.038400e+02
# Longitude                      1.134177e+02
# Latitude                      -2.461746e+00
# New Cases per Million          5.710000e+00
# Total Cases per Million        6.804285e+03
# New Deaths per Million         0.000000e+00
# Total Deaths per Million       1.584150e+02
# Total Deaths per 100rb         1.584000e+01
# Growth Factor of New Cases     1.000000e+00
# Growth Factor of New Deaths    1.000000e+00
# dtype: float64
# /var/folders/4s/n8nwg7s545s2kjgr2ts9qlkc0000gn/T/ipykernel_61688/2279890642.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(data.median())

# %%
print(data.mode())
# Out:
#           Date Location ISO Code     Location  New Cases  New Deaths  \
# 0     1/1/2021             ID-JK  DKI Jakarta        0.0         0.0
# 1     1/1/2022               IDN    Indonesia        NaN         NaN
# 2    1/10/2021               NaN          NaN        NaN         NaN
# 3    1/10/2022               NaN          NaN        NaN         NaN
# 4    1/11/2021               NaN          NaN        NaN         NaN
# ..         ...               ...          ...        ...         ...
# 883   9/8/2021               NaN          NaN        NaN         NaN
# 884   9/8/2022               NaN          NaN        NaN         NaN
# 885   9/9/2020               NaN          NaN        NaN         NaN
# 886   9/9/2021               NaN          NaN        NaN         NaN
# 887   9/9/2022               NaN          NaN        NaN         NaN
#
#      New Recovered  New Active Cases  Total Cases  Total Deaths  \
# 0              0.0               0.0          1.0           1.0
# 1              NaN               NaN          NaN           NaN
# 2              NaN               NaN          NaN           NaN
# 3              NaN               NaN          NaN           NaN
# 4              NaN               NaN          NaN           NaN
# ..             ...               ...          ...           ...
# 883            NaN               NaN          NaN           NaN
# 884            NaN               NaN          NaN           NaN
# 885            NaN               NaN          NaN           NaN
# 886            NaN               NaN          NaN           NaN
# 887            NaN               NaN          NaN           NaN
#
#      Total Recovered  ...  Latitude New Cases per Million  \
# 0                1.0  ... -6.204699                   0.0
# 1                NaN  ... -0.789275                   NaN
# 2                NaN  ...       NaN                   NaN
# 3                NaN  ...       NaN                   NaN
# 4                NaN  ...       NaN                   NaN
# ..               ...  ...       ...                   ...
# 883              NaN  ...       NaN                   NaN
# 884              NaN  ...       NaN                   NaN
# 885              NaN  ...       NaN                   NaN
# 886              NaN  ...       NaN                   NaN
# 887              NaN  ...       NaN                   NaN
#
#      Total Cases per Million New Deaths per Million Total Deaths per Million  \
# 0                   11775.71                    0.0                      0.0
# 1                        NaN                    NaN                      NaN
# 2                        NaN                    NaN                      NaN
# 3                        NaN                    NaN                      NaN
# 4                        NaN                    NaN                      NaN
# ..                       ...                    ...                      ...
# 883                      NaN                    NaN                      NaN
# 884                      NaN                    NaN                      NaN
# 885                      NaN                    NaN                      NaN
# 886                      NaN                    NaN                      NaN
# 887                      NaN                    NaN                      NaN
#
#     Total Deaths per 100rb Case Fatality Rate Case Recovered Rate  \
# 0                      0.0              0.00%               0.00%
# 1                      NaN                NaN                 NaN
# 2                      NaN                NaN                 NaN
# 3                      NaN                NaN                 NaN
# 4                      NaN                NaN                 NaN
# ..                     ...                ...                 ...
# 883                    NaN                NaN                 NaN
# 884                    NaN                NaN                 NaN
# 885                    NaN                NaN                 NaN
# 886                    NaN                NaN                 NaN
# 887                    NaN                NaN                 NaN
#
#     Growth Factor of New Cases  Growth Factor of New Deaths
# 0                          1.0                          1.0
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                          NaN                          NaN
# ..                         ...                          ...
# 883                        NaN                          NaN
# 884                        NaN                          NaN
# 885                        NaN                          NaN
# 886                        NaN                          NaN
# 887                        NaN                          NaN
#
# [888 rows x 38 columns]

# %% [markdown]
# CARI MEASURE OF VARIANCE
# - range
# - interquartile range
# - standard deviation

# %%
# data_num = data.drop(columns = ['City or Regency'], inplace=True)

for col in columns_num:
    print(data[col].name + ' range: ' + str(data[col].max() - data[col].min()))
# Out:
# New Cases range: 64718
# New Deaths range: 2069
# New Recovered range: 61361
# New Active Cases range: 69103
# Total Cases range: 6405043
# Total Deaths range: 157876
# Total Recovered range: 6218708
# Total Active Cases range: 588456
# City or Regency range: nan
# Total Regencies range: 415
# Total Cities range: 97.0
# Total Districts range: 7186
# Total Urban Villages range: 8453.0
# Total Rural Villages range: 74678.0
# Area (km2) range: 1916243
# Population range: 264537113
# Population Density range: 16325.72
# Longitude range: 41.785508260000015
# Latitude range: 12.907819627999999
# New Cases per Million range: 1459.04
# Total Cases per Million range: 130231.61
# New Deaths per Million range: 63.8
# Total Deaths per Million range: 1632.6
# Total Deaths per 100rb range: 163.26
# Growth Factor of New Cases range: 175.0
# Growth Factor of New Deaths range: 134.5

# %%
# QUARTER 1, QUARTER 2, QUARTER 3 of data
# Boxplot median = Q2
# IQR = Q3 - Q1
# MINIMUM = Q1 - 1.5*IQR
# MAXIMUM = Q3 + 1.5*IQR

## In Normal Distribution, outliers have Z Score more than 3 or less than -3.

print(data.quantile([0.25, 0.5, 0.75]).T)
# Out:
#                                      0.25          0.50          0.75
# New Cases                    3.000000e+00  2.700000e+01  1.300000e+02
# New Deaths                   0.000000e+00  0.000000e+00  3.000000e+00
# New Recovered                2.000000e+00  2.000000e+01  1.230000e+02
# New Active Cases            -1.200000e+01  0.000000e+00  1.900000e+01
# Total Cases                  5.223250e+03  2.359650e+04  6.992775e+04
# Total Deaths                 1.280000e+02  5.655000e+02  2.189000e+03
# Total Recovered              3.913500e+03  2.102750e+04  6.414200e+04
# Total Active Cases           8.000000e+01  5.570000e+02  2.279000e+03
# City or Regency                       NaN           NaN           NaN
# Total Regencies              7.000000e+00  1.100000e+01  1.800000e+01
# Total Cities                 1.000000e+00  2.000000e+00  4.000000e+00
# Total Districts              1.030000e+02  1.690000e+02  2.890000e+02
# Total Urban Villages         9.900000e+01  1.750000e+02  3.320000e+02
# Total Rural Villages         9.280000e+02  1.591000e+03  2.853000e+03
# Area (km2)                   1.678700e+04  4.201300e+04  7.546800e+04
# Population                   1.999539e+06  4.216171e+06  9.095591e+06
# Population Density           4.779000e+01  1.038400e+02  2.627000e+02
# Longitude                    1.061090e+02  1.134177e+02  1.212011e+02
# Latitude                    -6.204699e+00 -2.461746e+00  2.120369e-01
# New Cases per Million        8.300000e-01  5.710000e+00  2.229000e+01
# Total Cases per Million      1.291367e+03  6.804285e+03  1.455736e+04
# New Deaths per Million       0.000000e+00  0.000000e+00  5.400000e-01
# Total Deaths per Million     3.886250e+01  1.584150e+02  3.899100e+02
# Total Deaths per 100rb       3.890000e+00  1.584000e+01  3.899000e+01
# Growth Factor of New Cases   6.700000e-01  1.000000e+00  1.250000e+00
# Growth Factor of New Deaths  8.800000e-01  1.000000e+00  1.000000e+00

# %%
IQR = data.quantile(0.75) - data.quantile(0.25)
print(IQR)
# Out:
# New Cases                      1.270000e+02
# New Deaths                     3.000000e+00
# New Recovered                  1.210000e+02
# New Active Cases               3.100000e+01
# Total Cases                    6.470450e+04
# Total Deaths                   2.061000e+03
# Total Recovered                6.022850e+04
# Total Active Cases             2.199000e+03
# City or Regency                         NaN
# Total Regencies                1.100000e+01
# Total Cities                   3.000000e+00
# Total Districts                1.860000e+02
# Total Urban Villages           2.330000e+02
# Total Rural Villages           1.925000e+03
# Area (km2)                     5.868100e+04
# Population                     7.096052e+06
# Population Density             2.149100e+02
# Longitude                      1.509209e+01
# Latitude                       6.416736e+00
# New Cases per Million          2.146000e+01
# Total Cases per Million        1.326599e+04
# New Deaths per Million         5.400000e-01
# Total Deaths per Million       3.510475e+02
# Total Deaths per 100rb         3.510000e+01
# Growth Factor of New Cases     5.800000e-01
# Growth Factor of New Deaths    1.200000e-01
# dtype: float64

# %%
print(data.std())
# Out:
# New Cases                      2.320630e+03
# New Deaths                     6.413908e+01
# New Recovered                  2.199879e+03
# New Active Cases               1.219513e+03
# Total Cases                    6.264435e+05
# Total Deaths                   1.769373e+04
# Total Recovered                5.958536e+05
# Total Active Cases             2.853741e+04
# City or Regency                         NaN
# Total Regencies                6.835973e+01
# Total Cities                   1.616894e+01
# Total Districts                1.192995e+03
# Total Urban Villages           1.402801e+03
# Total Rural Villages           1.240712e+04
# Area (km2)                     3.187865e+05
# Population                     4.461714e+07
# Population Density             2.729432e+03
# Longitude                      9.862068e+00
# Latitude                       3.608065e+00
# New Cases per Million          7.430971e+01
# Total Cases per Million        1.647739e+04
# New Deaths per Million         1.933016e+00
# Total Deaths per Million       3.634287e+02
# Total Deaths per 100rb         3.634288e+01
# Growth Factor of New Cases     2.597639e+00
# Growth Factor of New Deaths    1.276486e+00
# dtype: float64
# /var/folders/4s/n8nwg7s545s2kjgr2ts9qlkc0000gn/T/ipykernel_61688/691007357.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(data.std())

# %% [markdown]
# Another famous idea by Tukey is how to use his 5-number summary for detecting outlier. The gist is that data that deviates from the median above certain threshold will be flagged as outlier. This formula is only works if the distribution is not normal.

# %% [markdown]
# MISSING VALUE
# - normal = input mean
# - tidak normal = input median
# - categorical = input mode
